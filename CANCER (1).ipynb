# %% [markdown]
# **PROBLEM DEFINITION**

# %% [markdown]
# This analysis explores the relationship between various health factors, such as smoking and alcohol consumption, and their influence on both the occurrence (incidence) and mortality rates of cancer using data on cancer deaths with contributing factors.

# %% [markdown]
# **DATA UNDERSTANDING**

# %%
#data loading
#importing library
import pandas as pd
cd=pd.read_excel("/content/Cancer (1).xlsx")
cd
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# ...

# %% [markdown]
# This displays the initial and final five columns in the dataset.

# %%
#head
cd.head()
# Out:
#   Country or Territory  \
# 0          Afghanistan
# 1              Algeria
# 2           Azerbaijan
# 3              Albania
# 4              Armenia
#
#   Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                0.5
# 1                                                1.1
# 2                                                3.2
# 3                                                4.9
# 4                                                  5
#
#   Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 0                                               21.4
# 1                                               17.5
# 2                                               36.7
# 3                                               40.9
# 4                                               43.5
#
#   Smoking prevalence female\nPrevalence (%) of daily smoking for women  \
# ...

# %% [markdown]
# The first five rows are displayed

# %%
#tail
cd.tail()
# Out:
#     Country or Territory  \
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
#     Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
# ...

# %% [markdown]
# The last five rows of the dataset are displayed using the .tail() function

# %%
#dataset information
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 27 columns):
#  #   Column                                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                                     --------------  -----
#  0   Country or Territory                                                                                                                                       207 non-null    object
#  1   Cancer deaths attributable to alcohol
# Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016                       207 non-null    object
#  2   Smoking prevalence male
# ...

# %% [markdown]
# The data type of this dataset is object and the total size of the data is 43.8 kilobytes.

# %%
#Picking relevant data columns
general_selected_columns = [
'Country or Territory',
'Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016',
'Cancer rank as leading cause of death among 30-69\n2016',
'Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country',
'Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018',
'Cervical cancer incidence rates\nAge-standardized rate (world) per 100,000, 2018',
'Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018',
'Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018',
'Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018',
'Most common cancer cases worldwide, females\n2018',
'Most common cancer cases worldwide, males\n2018',
'Most common cancer deaths worldwide, females\n2018',
'Most common cancer deaths worldwide, males\n2018',
'Radiotherapy availability\nNumber of radiotherapy machines per 1,000 cancer patients',
'Smoking prevalence female\nPrevalence (%) of daily smoking for women',
'Smoking prevalence male\nPrevalence (%) of daily smoking for men',
'Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016',
'Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016'
 ]
selected_general_cd = cd[general_selected_columns]
selected_general_cd
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# ...

# %% [markdown]
# This shows the first and last 5 columns of the data picked. These columns will be relevant for analyzing the whole dataset.

# %%
# Display data types of columns
print("\nData types of columns in selected_general_cda:")
print(selected_general_cd.dtypes)
# Out:
# Data types of columns in selected_general_cda:
# Country or Territory                                                                                                                     object
# Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016    object
# Cancer rank as leading cause of death among 30-69\n2016                                                                                  object
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country                                     object
# Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018     object
# Cervical cancer incidence rates\nAge-standardized rate (world) per 100,000, 2018                                                         object
# ...

# %% [markdown]
# The only data type found in this dataset is object

# %%
selected_columns = ['Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018',
                           'Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018',
                           'Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018',
                           'Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018',
                           'Smoking prevalence female\nPrevalence (%) of daily smoking for women',
                           'Smoking prevalence male\nPrevalence (%) of daily smoking for men',
                           'Radiotherapy availability\nNumber of radiotherapy machines per 1,000 cancer patients',
                           'Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018',
                           'Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016',
                           'Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016'
                            ]
selected_cd = selected_general_cd[selected_columns]
selected_cd
# Out:
#     Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018  \
# 0                                                  151
# 1                                                312.6
# 2                                                228.1
# 3                                                401.1
# 4                                                402.2
# ..                                                 ...
# 202                                              590.1
# 203                                              661.9
# 204                                              776.5
# 205                                                418
# 206                                                747
#
#     Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018  \
# 0                                                  3.2
# 1                                                  2.9
# ...

# %% [markdown]
# We'll be focusing on these 10 columns to analyze and understand the data better

# %%
#Shape of the DataFrame
print("Shape of selected_cd:", selected_cd.shape)
# Out:
# Shape of selected_cd: (207, 10)

# %% [markdown]
# There are 207 rows and 10 columns in the DataFrame.

# %%
#displaying the first five rows of the dataset
print("\nFirst few rows of selected_cd:")
selected_cd.head()
# Out:
# First few rows of selected_cd:
#   Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018  \
# 0                                                151
# 1                                              312.6
# 2                                              228.1
# 3                                              401.1
# 4                                              402.2
#
#   Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018  \
# 0                                                3.2
# 1                                                2.9
# 2                                                2.6
# 3                                                7.1
# 4                                                8.5
#
#   Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018  \
# 0                                                9.4
# ...

# %% [markdown]
# These are the last 5 rows of the selected columns in our dataset

# %%
#Displaying the data types of columns
print("\nData types of columns in selected_cd:")
print(selected_cd.dtypes)
# Out:
# Data types of columns in selected_cd:
# Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018    object
# Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018                                          object
# Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018                                            object
# Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018                                             object
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                    object
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                        object
# ...

# %% [markdown]
# All the columns in selected_cd are of object data type

# %%
#Changing all columns to numeric types
selected_cd = selected_cd.apply(pd.to_numeric, errors='coerce')

#Print dataframe
print(selected_cd)
# Out:
#      Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018  \
# 0                                                151.0
# 1                                                312.6
# 2                                                228.1
# 3                                                401.1
# 4                                                402.2
# ..                                                 ...
# 202                                              590.1
# 203                                              661.9
# 204                                              776.5
# 205                                              418.0
# 206                                              747.0
#
#      Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018  \
# 0                                                  3.2
# 1                                                  2.9
# ...

# %% [markdown]
# The data in the selected columns have been converted to numeric

# %%
#Displaying data types of columns
print("\nData types of columns in selected_cd:")
print(selected_cd.dtypes)
# Out:
# Data types of columns in selected_cd:
# Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018    float64
# Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018                                          float64
# Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018                                            float64
# Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018                                             float64
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                    float64
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                        float64
# ...

# %% [markdown]
# The data type in all the columns in selected_cd are object

# %%
#Changing all columns to numeric types
selected_cd = selected_cd.apply(pd.to_numeric, errors='coerce')

#Print the dataframe
print(selected_cd)
# Out:
#      Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018  \
# 0                                                151.0
# 1                                                312.6
# 2                                                228.1
# 3                                                401.1
# 4                                                402.2
# ..                                                 ...
# 202                                              590.1
# 203                                              661.9
# 204                                              776.5
# 205                                              418.0
# 206                                              747.0
#
#      Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018  \
# 0                                                  3.2
# 1                                                  2.9
# ...

# %% [markdown]
# The data in the selected columns has been converted to numeric

# %%
#Displaying data types of columns
print("\nData types of columns in selected_cd:")
print(selected_cd.dtypes)
# Out:
# Data types of columns in selected_cd:
# Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018    float64
# Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018                                          float64
# Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018                                            float64
# Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018                                             float64
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                    float64
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                        float64
# ...

# %% [markdown]
# The data type in selected_cd is object

# %%
#Checking for missing Values
missing_values = selected_cd.isnull().sum()
missing_values
# Out:
# Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018    22
# Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018                                          23
# Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018                                            22
# Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018                                             29
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                    16
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                        18
# Radiotherapy availability\nNumber of radiotherapy machines per 1,000 cancer patients                                                    25
# ...

# %%
Missing values are found in the selected columns of the dataset

# %%
#checking for duplicates
duplicates = selected_cd.duplicated().sum()
duplicates
# Out:
# 8

# %% [markdown]
# There are 8 duplicate valueS in the dataset

# %% [markdown]
# # **DATA CLEANING**

# %%
#Droping of rows with duplicated values
selected_cd.drop_duplicates(inplace=True)

# %%
#check for duplicates
duplicates = selected_cd.duplicated().sum()
print("number of duplicates", duplicates)
# Out:
# number of duplicates 0

# %% [markdown]
# Duplicate values have been successfully removed from the data

# %%
#Droping rows with missing values
selected_cd.dropna(subset=selected_columns, inplace=True)

# %%
#Checking for missing values
missing_values = selected_cd.isnull().sum()

#Print the number of missing values in each column
print("\nNumber of missing values in each column:")
print(missing_values)
# Out:
# Number of missing values in each column:
# Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018    0
# Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018                                          0
# Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018                                            0
# Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018                                             0
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                    0
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                        0
# ...

# %% [markdown]
# All missing values have been dropped from the data.

# %%
#Checking for completeness
completeness = selected_cd.notnull().sum() / len(selected_cd) * 100
print(completeness)
# Out:
# Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018    100.0
# Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018                                          100.0
# Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018                                            100.0
# Melanoma skin cancer incidence\nAge-standardized rate (world) per 100,000, both sexes, 2018                                             100.0
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                    100.0
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                        100.0
# ...

# %% [markdown]
# The data is complete in all the 10 columns

# %%
#Displaying the shape of the DataFrame after dropping missing values
print("\nShape of the DataFrame after dropping missing values:")
print(selected_cd.shape)
# Out:
# Shape of the DataFrame after dropping missing values:
# (164, 10)

# %% [markdown]
# The cleaned data has 164 rows and 10 columns

# %% [markdown]
# # EXPLOLATORY DATA ANALYSIS

# %%
#Displaying summary statistics for the selected columns
print("\nDescriptive statistics for the numeric columns:")
print(selected_cd.describe())
# Out:
# Descriptive statistics for the numeric columns:
#        Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018  \
# count                                         164.000000
# mean                                          443.838415
# std                                           315.681201
# min                                            89.100000
# 25%                                           213.525000
# 50%                                           320.200000
# 75%                                           592.275000
# max                                          1849.800000
#
#        Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018  \
# count                                         164.000000
# mean                                            9.476646
# std                                             8.779965
# ...

# %% [markdown]
# Summary statistics for the selected columns are shown, including the count, mean, standard deviation, minimum, 25th percentile, median (50th percentile), 75th percentile, and maximum values.

# %%
#Correlation analysis
import seaborn as sns
import matplotlib.pyplot as plt
# Calculate the correlation matrix
correlation_matrix = selected_cd.corr()
correlation_matrix
# Out:
#                                                     Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018  \
# Cancer survivors\nEstimated number of cancer su...                                           1.000000
# Lung cancer incidence rates, female\nAge-standa...                                           0.804433
# Lung cancer incidence rates, male\nAge-standard...                                           0.608835
# Melanoma skin cancer incidence\nAge-standardize...                                           0.874856
# Smoking prevalence female\nPrevalence (%) of da...                                           0.695555
# Smoking prevalence male\nPrevalence (%) of dail...                                           0.026245
# Radiotherapy availability\nNumber of radiothera...                                           0.498925
# ...

# %%
#plotting of histograms

import matplotlib.pyplot as plt

#Create a histogram for each selected column
for col in selected_cd:
  plt.figure()
  plt.hist(selected_cd[col], bins=10)
  plt.xlabel(col)
  plt.ylabel("Frequency")
  plt.title(f"Histogram of {col}")
  plt.show()

# %% [markdown]
# These histograms display the frequency of health factors for each column, illustrating how these factors impact people of different ages in relation to cancer prevalence per 100,000 individuals.

# %%
#A heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# The correlation matrix above shows the relationships between various health factors.

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize = (15,8))
values = selected_general_cd['Cancer rank as leading cause of death among 30-69\n2016']
#creating the bar plot
plt.bar(selected_general_cd['Cancer rank as leading cause of death among 30-69\n2016'], values, color ='blue', width=0.5)
plt.xlabel("Cancer rank as leading cause of death among 30-69\n2016")
plt.title("Rank")
plt.show()

# %% [markdown]
# The bar graph illustrates cancer's ranking as a leading cause of death in different countries. In some countries, cancer ranked first, while in others, it ranked third or fourth, and even fifth. Data was not available for most countries, but the ranking is evident in those with available information.

# %%
#Cancer rank as leading cause of death among 30-69
#2016 vs Most common cancer cases worldwide, females
#2018

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Most common cancer cases worldwide, females\n2018'].value_counts()
    for x_label, grp in selected_general_cd.groupby('Cancer rank as leading cause of death among 30-69\n2016')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Cancer rank as leading cause of death among 30-69\n2016')
_ = plt.ylabel('Most common cancer cases worldwide, females\n2018')

# %% [markdown]
# This graph depicts the rank of cancer as the leading cause of death among individuals aged 30-69 compared to the most common cases worldwide among females in 2016.

# %%
# Most common cancer cases worldwide, females
#2018 vs Most common cancer deaths worldwide, females
#2018

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Most common cancer deaths worldwide, females\n2018'].value_counts()
    for x_label, grp in selected_general_cd.groupby('Most common cancer cases worldwide, females\n2018')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Most common cancer cases worldwide, females\n2018')
_ = plt.ylabel('Most common cancer deaths worldwide, females\n2018')

# %% [markdown]
# This graph depicts the ranking of cancer as a leading cause of death among individuals aged 30-69 compared to the most common cases worldwide in females in 2016.

# %%
#Cancer rank as leading cause of death among 30-69
#2016 vs Most common cancer cases worldwide, females
#2018

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Most common cancer cases worldwide, females\n2018'].value_counts()
    for x_label, grp in selected_general_cd.groupby('Cancer rank as leading cause of death among 30-69\n2016')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Cancer rank as leading cause of death among 30-69\n2016')
_ = plt.ylabel('Most common cancer cases worldwide, females\n2018')

# %% [markdown]
# This graph illustrates the ranking of cancer as the leading cause of death among individuals aged 30-69 compared to the most common cancer cases in females worldwide in 2016.

# %%
#Most common cancer deaths worldwide, females
2018

from matplotlib import pyplot as plt
import seaborn as sns
selected_general_cd.groupby('Most common cancer deaths worldwide, females\n2018').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# The bar graph shows the most common cancer-related deaths among females worldwide in 2018, with breast cancer being the leading cause of death and liver cancer being the least common.

# %%
#Most common cancer cases worldwide, females
2018

from matplotlib import pyplot as plt
import seaborn as sns
selected_general_cd.groupby('Most common cancer cases worldwide, females\n2018').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# This bar graph illustrates the prevalence of various cancer types among females worldwide in 2018, with breast cancer cases being the most common, and liver, lung, and thyroid cancer cases being among the least common.

# %%
#Cancer rank as leading cause of death among 30-69
2016
from matplotlib import pyplot as plt
import seaborn as sns
selected_general_cd.groupby('Cancer rank as leading cause of death among 30-69\n2016').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# The bar graph above shows how cancer ranked as the leading cause of death among individuals aged 30-69 in different regions in 2016. It ranked 2nd in most regions, 5th in a few, and there was no data available for other places.

# %% [markdown]
# # Findings:
# 1. Breast cancer ranks as the most prevalent cancer type among females.
#
# 2. Patients with lung cancer generally have lower survival rates compared to those with melanoma.
#
# 3. Breast cancer stands as the primary cause of cancer-related deaths in females, followed by cervical cancer.
#
# 4. Cancer ranks second among the leading causes of death in many countries.
#
# 5. Lung cancer incidence rates are notably high among young age groups, particularly children aged 0-10 years.
#
# 6. Radiotherapy machines have significantly enhanced survival rates for lung cancer patients.
#
# 7. Radiotherapy has been shown to offer more benefits to female smokers compared to male smokers.

# %% [markdown]
# # **CONCLUSION:**
# Based on this data, it is evident that cancer remains a significant global cause of mortality.
#
# The data from the radiotherapy machine suggests that men could improve their chances of surviving lung cancer by reducing smoking.
#
# And finally, the incidence of melanoma skin cancer is high among children aged 0-3 years.
